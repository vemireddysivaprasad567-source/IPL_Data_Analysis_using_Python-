# %%
# -------------------------IPL DATA  2007 TO 2024------------------------------
import pandas as pd
df=pd.read_csv('matches.csv')
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
#---------------------------FIRST 5 MATCHES----------------------------
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
# ----------------------------------LAST 5 MATCHES----------------------------
df.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
#---------------------STATISTICAL SUMMARY IN DATA--------------------------------
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
# ---------------------COLUMNS-----------------------
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
#-------------------NULL VALUES IN IPL DATA---------------------------------
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
#-------------------------MORE THAN 250 TARGET RUNS--------------------
df[df['target_runs']>250]
# Out:
#            id season           city        date match_type  player_of_match  \
# 352    598027   2013      Bangalore  2013-04-23     League         CH Gayle
# 987   1359512   2023     Chandigarh  2023-04-28     League       MP Stoinis
# 1031  1422126   2024      Hyderabad  2024-03-27     League  Abhishek Sharma
# 1039  1422134   2024  Visakhapatnam  2024-04-03     League        SP Narine
# 1053  1426268   2024      Bengaluru  2024-04-15     League          TM Head
# 1058  1426273   2024          Delhi  2024-04-20     League          TM Head
# 1065  1426280   2024        Kolkata  2024-04-26     League      JM Bairstow
# 1066  1426281   2024          Delhi  2024-04-27     League  J Fraser-McGurk
#
#                                                   venue  \
# 352                               M Chinnaswamy Stadium
# 987   Punjab Cricket Association IS Bindra Stadium, ...
# 1031  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1039  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# ...

# %%
#---------------------MUMBAI INDIANS WINNING MATCHES----------------------
df[df['winner']=='Mumbai Indians']
# Out:
#            id   season     city        date  match_type player_of_match  \
# 15     335997  2007/08  Kolkata  2008-04-29      League   ST Jayasuriya
# 22     336004  2007/08   Mumbai  2008-05-04      League      SM Pollock
# 26     336008  2007/08   Mumbai  2008-05-07      League         A Nehra
# 35     336018  2007/08   Mumbai  2008-05-14      League   ST Jayasuriya
# 37     336021  2007/08   Mumbai  2008-05-16      League      SM Pollock
# ...       ...      ...      ...         ...         ...             ...
# 1021  1370351     2023  Chennai  2023-05-24  Eliminator   Akash Madhwal
# 1043  1422138     2024   Mumbai  2024-04-07      League      R Shepherd
# 1048  1426263     2024   Mumbai  2024-04-11      League       JJ Bumrah
# 1056  1426271     2024   Mohali  2024-04-18      League       JJ Bumrah
# 1078  1426293     2024   Mumbai  2024-05-06      League        SA Yadav
#
#                                                   venue  \
# ...

# %%
#--------------------WHICH TEAM MORE NO OF WINS IN IPL 2007-2024----------------------------
df['winner'].value_counts().head(20)
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
#------------------BAR GRAPH WHICH TEAM MORE NO OF WINS IN IPL 2007-2024--------------------------
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))

df['winner'].value_counts().head(20).plot(kind='bar')

plt.title("Most Winning Teams")
plt.xlabel("Teams")
plt.ylabel("Wins")

plt.show()

# %%
#---------------------WHICH PLAYER NO OF PLAYER OF MATCHES IN IPL 2007-2024--------------------
df['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
#---------GRAPH-------------WHICH PLAYER NO OF PLAYER OF MATCHES IN IPL 2007-2024---------------------
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))

df['player_of_match'].value_counts().head(10).plot(kind='bar')

plt.title("Most player of matchs ")
plt.xlabel("Players")
plt.ylabel("No Of Times")

plt.show()

# %%
#------------ROHIT SHARMA WINS PLAYER OF MATCHES--------------------
df[df['player_of_match']=='RG Sharma']
# Out:
#           id   season           city        date match_type player_of_match  \
# 87    392212     2009      Centurion  2009-05-06     League       RG Sharma
# 103   392228     2009   Johannesburg  2009-05-16     League       RG Sharma
# 165   419156  2009/10     Dharamsala  2010-04-16     League       RG Sharma
# 256   548314     2012  Visakhapatnam  2012-04-09     League       RG Sharma
# 303   548363     2012        Kolkata  2012-05-12     League       RG Sharma
# 336   598011     2013         Mumbai  2013-04-13     League       RG Sharma
# 362   598037     2013         Mumbai  2013-04-29     League       RG Sharma
# 424   733983     2014         Mumbai  2014-05-06     League       RG Sharma
# 516   829823     2015        Kolkata  2015-05-24      Final       RG Sharma
# 521   980909     2016        Kolkata  2016-04-13     League       RG Sharma
# 530   980927     2016         Mumbai  2016-04-20     League       RG Sharma
# ...

# %%
#-----------------TOSS DECISION BAT OR FIELD---------------------
df['toss_decision'].value_counts()
# Out:
# toss_decision
# field    704
# bat      391
# Name: count, dtype: int64

# %%
#--------------TOSS DECISION PIE CHART------------------------
df['toss_decision'].value_counts().plot(
    kind='pie',
    autopct='%1.0f%%',explode=[0,0.2],shadow=True
)

plt.title("Toss Decision")
plt.ylabel("")

plt.show()

# %%
# Chennai Super Kings vs Mumbai Indians matches WINNING COUNT

csk_vs_mi = df[
    ((df['team1'] == 'Chennai Super Kings') & (df['team2'] == 'Mumbai Indians')) |
    ((df['team1'] == 'Mumbai Indians') & (df['team2'] == 'Chennai Super Kings'))
]

csk_vs_mi['winner'].value_counts()
# Out:
# winner
# Mumbai Indians         20
# Chennai Super Kings    17
# Name: count, dtype: int64

# %%
#--------------Chennai Super Kings vs Mumbai Indians matche---------------------------
csk_vs_mi = df[
    ((df['team1'] == 'Chennai Super Kings') & (df['team2'] == 'Mumbai Indians')) |
    ((df['team1'] == 'Mumbai Indians') & (df['team2'] == 'Chennai Super Kings'))
]

csk_vs_mi
# Out:
#            id   season            city        date         match_type  \
# 7      335989  2007/08         Chennai  2008-04-23             League
# 35     336018  2007/08          Mumbai  2008-05-14             League
# 58     392181     2009       Cape Town  2009-04-18             League
# 102    392227     2009  Port Elizabeth  2009-05-16             League
# 134    419125  2009/10          Mumbai  2010-03-25             League
# 151    419142  2009/10         Chennai  2010-04-06             League
# 174    419165  2009/10          Mumbai  2010-04-25              Final
# 197    501221     2011          Mumbai  2011-04-22             League
# 248    548306     2012         Chennai  2012-04-04             League
# 294    548355     2012          Mumbai  2012-05-06             League
# 319    548379     2012       Bangalore  2012-05-23  Elimination Final
# 326    598002     2013         Chennai  2013-04-06             League
# ...

# %%
#-----------------------NO OF WINS IN FINNAL------------------
a= df[df['match_type']=='Final']
a['winner'].value_counts()
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
#-------------------------------NO OF WINS IN FINNAL BAR GRAPH-------------------
import matplotlib.pyplot as plt
a['winner'].value_counts().plot(kind='bar')
plt.title('No Of matches for final')
plt.ylabel('No Of Wins')
plt.show()

# %%
#---------------MAX NO OF TOSS WINNER TEAMS-------------------------
df['toss_winner'].value_counts().head(20)
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Rajasthan Royals               120
# Royal Challengers Bangalore    113
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Royal Challengers Bengaluru      8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
#-------------------MOST NO OF TOSS WINNER TEAMS IN GRAPH----------------
import matplotlib.pyplot as plt
df['toss_winner'].value_counts().head(10).plot(kind='bar')
plt.title('IPL Teams')
plt.ylabel('No Of times toss wins')
plt.show()

# %%
#-----------2020 FINAL WINNER --------------------
final =df[(df['season']=='2020/21')&(df['match_type']=='Final')]
final[['team1','team2','winner','player_of_match','venue']]
# Out:
#               team1           team2          winner player_of_match  \
# 815  Delhi Capitals  Mumbai Indians  Mumbai Indians        TA Boult
#
#                                    venue
# 815  Dubai International Cricket Stadium

# %%
#------------------2024 FINAL WINNER-------------------
wineer=df[(df['season']=='2024')&(df['match_type']=='Final')]
wineer['winner']
# Out:
# 1094    Kolkata Knight Riders
# Name: winner, dtype: object

# %%
# MI vs CSK Final matches

mi_csk_final = df[
    (
        ((df['team1'] == 'Mumbai Indians') & (df['team2'] == 'Chennai Super Kings')) |
        ((df['team1'] == 'Chennai Super Kings') & (df['team2'] == 'Mumbai Indians'))
    )
    &
    (df['match_type'] == 'Final')
]

# Display matches
mi_csk_final[['season', 'team1', 'team2', 'winner']]
# Out:
#       season                team1                team2               winner
# 174  2009/10  Chennai Super Kings       Mumbai Indians  Chennai Super Kings
# 397     2013  Chennai Super Kings       Mumbai Indians       Mumbai Indians
# 516     2015       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 755     2019       Mumbai Indians  Chennai Super Kings       Mumbai Indians

# %%
# -----------------FINAL MATCHES WINNER IN SEASON WISE AND PLAYER OF MATCHES WINNER-----------------
finals = df[df['match_type'] == 'Final']

finals[['season','winner','player_of_match']]
# Out:
#        season                 winner player_of_match
# 57    2007/08       Rajasthan Royals       YK Pathan
# 114      2009        Deccan Chargers        A Kumble
# 174   2009/10    Chennai Super Kings        SK Raina
# 247      2011    Chennai Super Kings         M Vijay
# 321      2012  Kolkata Knight Riders        MS Bisla
# 397      2013         Mumbai Indians      KA Pollard
# 457      2014  Kolkata Knight Riders       MK Pandey
# 516      2015         Mumbai Indians       RG Sharma
# 576      2016    Sunrisers Hyderabad     BCJ Cutting
# 635      2017         Mumbai Indians       KH Pandya
# 695      2018    Chennai Super Kings       SR Watson
# 755      2019         Mumbai Indians       JJ Bumrah
# 815   2020/21         Mumbai Indians        TA Boult
# 875      2021    Chennai Super Kings    F du Plessis
# 949      2022         Gujarat Titans       HH Pandya
# 1023     2023    Chennai Super Kings       DP Conway
# 1094     2024  Kolkata Knight Riders        MA Starc

# %%
#-------------MOST MARGIN RUNS WINNERS---------------------
df[['winner','result_margin']].sort_values(by='result_margin', ascending=False).head()
# Out:
#                           winner  result_margin
# 620               Mumbai Indians          146.0
# 560  Royal Challengers Bangalore          144.0
# 0          Kolkata Knight Riders          140.0
# 496  Royal Challengers Bangalore          138.0
# 352  Royal Challengers Bangalore          130.0

# %%
#-----------------SEASON WISE TOTAL MACHES PLAY--------------------------
df['season'].value_counts().sort_index()
# Out:
# season
# 2007/08    58
# 2009       57
# 2009/10    60
# 2011       73
# 2012       74
# 2013       76
# 2014       60
# 2015       59
# 2016       60
# 2017       59
# 2018       60
# 2019       60
# 2020/21    60
# 2021       60
# 2022       74
# 2023       74
# 2024       71
# Name: count, dtype: int64

# %%
#--------------------SEASON WISE TOTAL MACHES PLAY IN LINE GRAPH------------------
df['season'].value_counts().sort_index().plot(kind='line',marker='o')
plt.title("Matches Per Season")

plt.xlabel("Season")
plt.ylabel("Matches")
plt.grid()

plt.show()

# %%
# -------------------------2021 PLAYER OF MATCH WINNERS------------------------
a=df[df['season']=='2021']
a[['player_of_match']]
# Out:
#      player_of_match
# 816         HV Patel
# 817         S Dhawan
# 818           N Rana
# 819        SV Samson
# 820        RD Chahar
# 821       GJ Maxwell
# 822       JD Unadkat
# 823        DL Chahar
# 824       KA Pollard
# 825   AB de Villiers
# 826         S Dhawan
# 827           MM Ali
# 828         A Mishra
# 829      JM Bairstow
# 830     F du Plessis
# 831       D Padikkal
# 832         KL Rahul
# 833        CH Morris
# 834        RA Jadeja
# 835          PP Shaw
# 836       EJG Morgan
# 837   AB de Villiers
# 838       RD Gaikwad
# 839        Q de Kock
# 840          PP Shaw
# 841    Harpreet Brar
# 842       KA Pollard
# 843       JC Buttler
# 844       MA Agarwal
# 845       RD Gaikwad
# 846         CV Varun
# 847     Kartik Tyagi
# 848         A Nortje
# 849        SP Narine
# 850         DJ Bravo
# 851          SS Iyer
# 852        JO Holder
# 853        RA Jadeja
# 854       GJ Maxwell
# 855           JJ Roy
# 856        SP Narine
# 857       KA Pollard
# ...

# %%
#------------------------2021 FINAL MATCH PLAYER OF MATCH WINNER-------------------------
a=df[(df['season']=='2021')&(df['match_type']=='Final')]
a[['player_of_match']]
# Out:
#     player_of_match
# 875    F du Plessis

# %%
# 805rd row data

df.iloc[[805]]
# Out:
#           id   season       city        date match_type player_of_match  \
# 805  1216537  2020/21  Abu Dhabi  2020-10-30     League       BA Stokes
#
#                     venue            team1             team2  \
# 805  Sheikh Zayed Stadium  Kings XI Punjab  Rajasthan Royals
#
#           toss_winner toss_decision            winner   result  result_margin  \
# 805  Rajasthan Royals         field  Rajasthan Royals  wickets            7.0
#
#      target_runs  target_overs super_over method      umpire1 umpire2
# 805        186.0          20.0          N    NaN  CB Gaffaney  S Ravi

# %%
#--------------------NULL VALUES COUNTS-----------------------------
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
#-------------------NULL VALUES IN CITY FILL WITH MUMBAI----------------------------
df['city']=df['city'].fillna('Mumbai')
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
#-----------------------MOST MATCHES PLAYES VENUE -------------------------------------------
df['venue'].value_counts().head(10)
# Out:
# venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Wankhede Stadium, Mumbai                      45
# Punjab Cricket Association Stadium, Mohali    35
# Name: count, dtype: int64

# %%
#--------------MOST MATCHES PLAYES VENUE BAR GRAPH------------------------
import matplotlib.pyplot as plt
df['venue'].value_counts().head(10).plot(kind='bar')
plt.title('Play the Grounds ')
plt.xlabel('venue')
plt.ylabel('No Of Matches')
plt.show()

# %%
#-----------------------FINAL MATCHES WINNERS IS CSK AND MI----------------------
df[(df['winner'].isin(['Mumbai Indians','Chennai Super Kings']))&(df['match_type']=='Final')]
# Out:
#            id   season       city        date match_type player_of_match  \
# 174    419165  2009/10     Mumbai  2010-04-25      Final        SK Raina
# 247    501271     2011    Chennai  2011-05-28      Final         M Vijay
# 397    598073     2013    Kolkata  2013-05-26      Final      KA Pollard
# 516    829823     2015    Kolkata  2015-05-24      Final       RG Sharma
# 635   1082650     2017  Hyderabad  2017-05-21      Final       KH Pandya
# 695   1136620     2018     Mumbai  2018-05-27      Final       SR Watson
# 755   1181768     2019  Hyderabad  2019-05-12      Final       JJ Bumrah
# 815   1237181  2020/21        NaN  2020-11-10      Final        TA Boult
# 875   1254117     2021      Dubai  2021-10-15      Final    F du Plessis
# 1023  1370353     2023  Ahmedabad  2023-05-29      Final       DP Conway
#
#                                           venue                team1  \
# 174                  Dr DY Patil Sports Academy  Chennai Super Kings
# ...

# %%
#-----------------------------ROHIT SHARMA WIN THE PLAYER OF MATCH IN FINAL----------------------------
df[(df['winner']=='Mumbai Indians')&(df['player_of_match']=='RG Sharma')&(df['match_type']=='Final')]
# Out:
#          id season     city        date match_type player_of_match  \
# 516  829823   2015  Kolkata  2015-05-24      Final       RG Sharma
#
#             venue           team1                team2          toss_winner  \
# 516  Eden Gardens  Mumbai Indians  Chennai Super Kings  Chennai Super Kings
#
#     toss_decision          winner result  result_margin  target_runs  \
# 516         field  Mumbai Indians   runs           41.0        203.0
#
#      target_overs super_over method          umpire1         umpire2
# 516          20.0          N    NaN  HDPK Dharmasena  RK Illingworth

# %%
#-----------------TOTAL WINS IN MUMBAI INDIANS-----------------------
df[df['winner']=='Mumbai Indians'].shape[0]
# Out:
# 144

# %%
# ---------------------------------MUMBAI INDIANS WINS MATCHES ONLY----------------------
df[df['winner']=='Mumbai Indians']
# Out:
#            id   season     city        date  match_type player_of_match  \
# 15     335997  2007/08  Kolkata  2008-04-29      League   ST Jayasuriya
# 22     336004  2007/08   Mumbai  2008-05-04      League      SM Pollock
# 26     336008  2007/08   Mumbai  2008-05-07      League         A Nehra
# 35     336018  2007/08   Mumbai  2008-05-14      League   ST Jayasuriya
# 37     336021  2007/08   Mumbai  2008-05-16      League      SM Pollock
# ...       ...      ...      ...         ...         ...             ...
# 1021  1370351     2023  Chennai  2023-05-24  Eliminator   Akash Madhwal
# 1043  1422138     2024   Mumbai  2024-04-07      League      R Shepherd
# 1048  1426263     2024   Mumbai  2024-04-11      League       JJ Bumrah
# 1056  1426271     2024   Mohali  2024-04-18      League       JJ Bumrah
# 1078  1426293     2024   Mumbai  2024-05-06      League        SA Yadav
#
#                                                   venue  \
# ...

# %%
#------------------------PLAY THE QUALIFIER 1 MATCHES IN ALL SEASONS------------------------------
df[df['match_type']=='Qualifier 1']
# Out:
#            id   season       city        date   match_type    player_of_match  \
# 244    501268     2011     Mumbai  2011-05-24  Qualifier 1           SK Raina
# 318    548378     2012       Pune  2012-05-22  Qualifier 1          YK Pathan
# 394    598070     2013      Delhi  2013-05-21  Qualifier 1         MEK Hussey
# 454    734043     2014    Kolkata  2014-05-27  Qualifier 1           UT Yadav
# 513    829817     2015     Mumbai  2015-05-19  Qualifier 1         KA Pollard
# 573    981013     2016  Bangalore  2016-05-24  Qualifier 1     AB de Villiers
# 632   1082647     2017     Mumbai  2017-05-16  Qualifier 1  Washington Sundar
# 692   1136617     2018     Mumbai  2018-05-22  Qualifier 1       F du Plessis
# 752   1181764     2019    Chennai  2019-05-07  Qualifier 1           SA Yadav
# 812   1237177  2020/21        NaN  2020-11-05  Qualifier 1          JJ Bumrah
# 872   1254114     2021      Dubai  2021-10-10  Qualifier 1         RD Gaikwad
# ...

# %%
#--------------------FINAL MATCHES WINNERS COUNT--------------------------
x=df[df['match_type']=='Final']
x['winner'].value_counts().head(10)
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
#------------------------FINAL MATCHES WINNERS IN BAR GRAPH------------------------------
import matplotlib.pyplot as plt
x['winner'].value_counts().head(10).plot(kind='bar')
plt.title('FINAL MATCHES WINNERS')
plt.xlabel('Teams')
plt.ylabel('No Of Times')
plt.show()

# %%
#-----------QUALIFIER 2 PLAY MATCHES COUNT-----------------------------
df[df['match_type']=='Qualifier 2'].shape[0]
# Out:
# 14

# %%
#-----------------------QUALIFIER 2 PLAY IN SEASON 2011------------------------
df[(df['match_type']=='Qualifier 2')&(df['season']=='2011')]
# Out:
#          id season     city        date   match_type player_of_match  \
# 246  501270   2011  Chennai  2011-05-27  Qualifier 2        CH Gayle
#
#                                venue                        team1  \
# 246  MA Chidambaram Stadium, Chepauk  Royal Challengers Bangalore
#
#               team2     toss_winner toss_decision  \
# 246  Mumbai Indians  Mumbai Indians         field
#
#                           winner result  result_margin  target_runs  \
# 246  Royal Challengers Bangalore   runs           43.0        186.0
#
#      target_overs super_over method    umpire1     umpire2
# 246          20.0          N    NaN  Asad Rauf  SJA Taufel

# %%
#----------------TOTAL PLAYS IN FINAL MATCHES------------------------
df[df['match_type']=='Final'].shape[0]
# Out:
# 17

# %%
#----------------------PLAYS IN FINAL MATCHES-------------------------------
df[df['match_type']=='Final']
# Out:
#            id   season          city        date match_type player_of_match  \
# 57     336040  2007/08        Mumbai  2008-06-01      Final       YK Pathan
# 114    392239     2009  Johannesburg  2009-05-24      Final        A Kumble
# 174    419165  2009/10        Mumbai  2010-04-25      Final        SK Raina
# 247    501271     2011       Chennai  2011-05-28      Final         M Vijay
# 321    548381     2012       Chennai  2012-05-27      Final        MS Bisla
# 397    598073     2013       Kolkata  2013-05-26      Final      KA Pollard
# 457    734049     2014     Bangalore  2014-06-01      Final       MK Pandey
# 516    829823     2015       Kolkata  2015-05-24      Final       RG Sharma
# 576    981019     2016     Bangalore  2016-05-29      Final     BCJ Cutting
# 635   1082650     2017     Hyderabad  2017-05-21      Final       KH Pandya
# 695   1136620     2018        Mumbai  2018-05-27      Final       SR Watson
# ...
